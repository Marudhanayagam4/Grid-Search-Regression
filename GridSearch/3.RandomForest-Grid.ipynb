# %%
# Data Collection
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Data preprocessing - nominal to numerical data - one hot encoding method
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# split train and test set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=0.3, random_state=0)
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
# Standardisation-Pre processing method - rescales data to a consistent format-easier to understand and use
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
X_test
# Out:
# array([[ 0.89459283, -0.08863026, -0.06746417,  1.02378711, -0.50466988],
#        [ 0.53757957, -0.22180837, -0.06746417, -0.97676557, -0.50466988],
#        [ 0.60898222,  1.57449152,  0.76341038,  1.02378711,  1.98149332],
#        ...,
#        [ 1.10880078,  1.20785059, -0.89833872,  1.02378711, -0.50466988],
#        [ 1.75142463,  1.34905148, -0.06746417,  1.02378711, -0.50466988],
#        [ 1.60861933, -0.92299913, -0.89833872, -0.97676557, -0.50466988]])

# %%
# Model creation
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={
    'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'n_estimators':[50,100],
    'max_features':['sqrt','log2',None]
}
grid=GridSearchCV(RandomForestRegressor(),param_grid, refit=True, verbose=5, n_jobs=-1)
grid.fit(X_train,Y_train) # training the model
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100]},
#              verbose=5)

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.252850      0.002569         0.011765        0.000964
# 1        0.492648      0.003851         0.019000        0.000913
# 2        0.245641      0.002442         0.011542        0.001135
# 3        0.500555      0.001754         0.019680        0.000740
# 4        0.308485      0.002857         0.011004        0.000953
# 5        0.607530      0.002647         0.018129        0.000940
# 6        0.611385      0.005773         0.009543        0.000274
# 7        1.194220      0.010691         0.018837        0.008507
# 8        0.594888      0.013232         0.010272        0.005726
# 9        1.191642      0.014974         0.013905        0.004598
# 10       0.997822      0.023317         0.009554        0.008319
# 11       2.038239      0.020784         0.018379        0.002898
# 12       0.235560      0.004691         0.008959        0.007798
# 13       0.477807      0.010140         0.019051        0.001781
# 14       0.246413      0.015219         0.015213        0.002833
# 15       0.495720      0.009613         0.014800        0.007061
# 16       0.312470      0.012692         0.011944        0.007142
# 17       0.638871      0.016246         0.017763        0.007155
# 18       0.273834      0.011166         0.007099        0.006228
# 19       0.541324      0.005434         0.021973        0.007374
# 20       0.269654      0.009394         0.015364        0.004559
# 21       0.534509      0.012080         0.014561        0.003801
# 22       0.350610      0.012723         0.009230        0.004278
# 23       0.656770      0.014361         0.020155        0.000037
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4    squared_error               None                 50
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 50
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 50
# 9   absolute_error               log2                100
# 10  absolute_error               None                 50
# 11  absolute_error               None                100
# 12    friedman_mse               sqrt                 50
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 50
# 15    friedman_mse               log2                100
# 16    friedman_mse               None                 50
# 17    friedman_mse               None                100
# 18         poisson               sqrt                 50
# 19         poisson               sqrt                100
# 20         poisson               log2                 50
# 21         poisson               log2                100
# 22         poisson               None                 50
# 23         poisson               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.863684
# 1   {'criterion': 'squared_error', 'max_features':...           0.857550
# 2   {'criterion': 'squared_error', 'max_features':...           0.861535
# 3   {'criterion': 'squared_error', 'max_features':...           0.861316
# 4   {'criterion': 'squared_error', 'max_features':...           0.860946
# 5   {'criterion': 'squared_error', 'max_features':...           0.859967
# 6   {'criterion': 'absolute_error', 'max_features'...           0.867085
# 7   {'criterion': 'absolute_error', 'max_features'...           0.864068
# 8   {'criterion': 'absolute_error', 'max_features'...           0.864815
# 9   {'criterion': 'absolute_error', 'max_features'...           0.860556
# 10  {'criterion': 'absolute_error', 'max_features'...           0.838805
# 11  {'criterion': 'absolute_error', 'max_features'...           0.852371
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.855371
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.859757
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.865453
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.861366
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.862943
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.862291
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856719
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858360
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.863270
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.860807
# 22  {'criterion': 'poisson', 'max_features': None,...           0.870736
# 23  {'criterion': 'poisson', 'max_features': None,...           0.858312
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.783053           0.803534           0.831290
# 1            0.792066           0.810916           0.823263
# 2            0.789981           0.798931           0.819534
# 3            0.787376           0.805212           0.828147
# 4            0.769852           0.816181           0.803486
# 5            0.765734           0.815563           0.800363
# 6            0.793725           0.815810           0.825694
# 7            0.793162           0.807323           0.822211
# 8            0.793480           0.812344           0.817359
# 9            0.787404           0.807859           0.824486
# 10           0.789777           0.805848           0.800873
# 11           0.772108           0.799830           0.798324
# 12           0.786876           0.808152           0.834227
# 13           0.782630           0.808235           0.829967
# 14           0.797059           0.815633           0.819239
# 15           0.796682           0.813334           0.822244
# 16           0.755036           0.812328           0.799706
# 17           0.760716           0.815768           0.798758
# 18           0.782845           0.811841           0.827966
# 19           0.795963           0.811391           0.825815
# 20           0.798340           0.811518           0.813667
# 21           0.791275           0.811521           0.831675
# 22           0.759146           0.816874           0.806487
# 23           0.768138           0.809072           0.800261
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.763932         0.809099        0.035274               14
# 1            0.772315         0.811222        0.028886                7
# 2            0.765976         0.807191        0.032152               16
# 3            0.767960         0.810002        0.032449               13
# 4            0.769003         0.803894        0.034007               17
# 5            0.765840         0.801493        0.035124               19
# 6            0.763842         0.813231        0.034299                2
# 7            0.766029         0.810559        0.032542                9
# 8            0.774239         0.812448        0.030286                3
# 9            0.771794         0.810420        0.030789               11
# 10           0.762116         0.799484        0.024816               23
# 11           0.763088         0.797144        0.031129               24
# 12           0.766477         0.810221        0.031867               12
# 13           0.771576         0.810433        0.031944               10
# 14           0.763441         0.812165        0.033178                4
# 15           0.761848         0.811095        0.032525                8
# 16           0.771614         0.800325        0.037258               22
# 17           0.767268         0.800960        0.036716               20
# 18           0.759318         0.807738        0.034027               15
# 19           0.768263         0.811959        0.030035                5
# 20           0.771417         0.811642        0.029882                6
# 21           0.775961         0.814248        0.029908                1
# 22           0.763767         0.803402        0.040631               18
# 23           0.766791         0.800515        0.033464               21

# %%
age=int(input("Age:"))
bmi=float(input("BMI:"))
children=int(input("Children:"))
sex_male=int(input("Sex_Male: 0/1"))
smoker_yes=int(input("Smoker_yes 0 / 1: "))

Future_predictions=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future predictions={}".format(Future_predictions))
# Out:
#   Cell In[16], line 8
#     print("Future predictions={}".format(Future_predictions:.2f))
#                                                              ^
# SyntaxError: invalid decimal literal
