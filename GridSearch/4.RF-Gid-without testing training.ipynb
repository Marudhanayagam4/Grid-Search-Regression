# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={
    'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'n_estimators':[50,100],
    'max_features':['sqrt','log2',None]
}
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.297115      0.009428         0.015284        0.009980
# 1        0.570396      0.002932         0.022522        0.005485
# 2        0.291180      0.006484         0.014764        0.002406
# 3        0.568368      0.011524         0.026341        0.005406
# 4        0.368355      0.005284         0.010817        0.007328
# 5        0.728303      0.015242         0.024895        0.001359
# 6        0.896724      0.013359         0.013523        0.004256
# 7        1.761466      0.025308         0.024827        0.007830
# 8        0.891053      0.014232         0.015685        0.000140
# 9        1.772330      0.023555         0.021667        0.004928
# 10       1.528371      0.017994         0.009400        0.007675
# 11       3.060425      0.028746         0.020114        0.004705
# 12       0.276863      0.010671         0.010603        0.005926
# 13       0.556179      0.004727         0.021391        0.003403
# 14       0.280682      0.001479         0.014968        0.002542
# 15       0.566616      0.008402         0.026439        0.010574
# 16       0.374064      0.006991         0.015842        0.005782
# 17       0.750588      0.014519         0.024814        0.004344
# 18       0.315473      0.004942         0.018553        0.006221
# 19       0.626597      0.004613         0.026645        0.002380
# 20       0.316840      0.006398         0.014728        0.004052
# 21       0.627648      0.007282         0.020218        0.006906
# 22       0.422795      0.002636         0.015811        0.001370
# 23       0.774604      0.103456         0.023895        0.009717
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4    squared_error               None                 50
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 50
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 50
# 9   absolute_error               log2                100
# 10  absolute_error               None                 50
# 11  absolute_error               None                100
# 12    friedman_mse               sqrt                 50
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 50
# 15    friedman_mse               log2                100
# 16    friedman_mse               None                 50
# 17    friedman_mse               None                100
# 18         poisson               sqrt                 50
# 19         poisson               sqrt                100
# 20         poisson               log2                 50
# 21         poisson               log2                100
# 22         poisson               None                 50
# 23         poisson               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.859369
# 1   {'criterion': 'squared_error', 'max_features':...           0.859367
# 2   {'criterion': 'squared_error', 'max_features':...           0.858572
# 3   {'criterion': 'squared_error', 'max_features':...           0.855486
# 4   {'criterion': 'squared_error', 'max_features':...           0.851234
# 5   {'criterion': 'squared_error', 'max_features':...           0.845770
# 6   {'criterion': 'absolute_error', 'max_features'...           0.855517
# 7   {'criterion': 'absolute_error', 'max_features'...           0.852390
# 8   {'criterion': 'absolute_error', 'max_features'...           0.863474
# 9   {'criterion': 'absolute_error', 'max_features'...           0.858020
# 10  {'criterion': 'absolute_error', 'max_features'...           0.836915
# 11  {'criterion': 'absolute_error', 'max_features'...           0.836353
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.858469
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.860081
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.855274
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.857854
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.840634
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.848593
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859698
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.855014
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.863069
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.853043
# 22  {'criterion': 'poisson', 'max_features': None,...           0.844195
# 23  {'criterion': 'poisson', 'max_features': None,...           0.849871
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.773661           0.859920           0.828068
# 1            0.782316           0.864000           0.829552
# 2            0.781028           0.857927           0.824702
# 3            0.783312           0.863438           0.832409
# 4            0.775609           0.852902           0.820494
# 5            0.770548           0.856911           0.817120
# 6            0.778150           0.846098           0.823664
# 7            0.782502           0.861092           0.825837
# 8            0.776935           0.856742           0.829449
# 9            0.780717           0.855841           0.829401
# 10           0.765961           0.848706           0.825161
# 11           0.772720           0.849026           0.819536
# 12           0.783146           0.853168           0.829796
# 13           0.777651           0.862512           0.829005
# 14           0.774981           0.862538           0.830254
# 15           0.773310           0.861275           0.830389
# 16           0.770480           0.855483           0.818726
# 17           0.772844           0.857022           0.821256
# 18           0.779720           0.849545           0.827608
# 19           0.776589           0.863391           0.827618
# 20           0.774321           0.864335           0.826426
# 21           0.782465           0.861559           0.820649
# 22           0.767025           0.855781           0.818489
# 23           0.775812           0.859692           0.819594
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.841135         0.832431        0.031717               10
# 1            0.837152         0.834477        0.029132                3
# 2            0.836763         0.831799        0.028468               14
# 3            0.840662         0.835061        0.028067                1
# 4            0.836966         0.827441        0.028425               18
# 5            0.837467         0.825563        0.030432               20
# 6            0.839150         0.828516        0.027245               17
# 7            0.844879         0.833340        0.027954                5
# 8            0.836820         0.832684        0.030536                8
# 9            0.844782         0.833752        0.028391                4
# 10           0.831777         0.821704        0.028918               24
# 11           0.835421         0.822611        0.026643               23
# 12           0.835294         0.831974        0.026650               13
# 13           0.843382         0.834526        0.030919                2
# 14           0.841335         0.832876        0.031022                6
# 15           0.840594         0.832684        0.031762                7
# 16           0.835957         0.824256        0.029335               22
# 17           0.835946         0.827132        0.029710               19
# 18           0.831922         0.829699        0.027572               15
# 19           0.838158         0.832154        0.030471               12
# 20           0.834134         0.832457        0.032779                9
# 21           0.844242         0.832392        0.028454               11
# 22           0.839823         0.825063        0.031430               21
# 23           0.839231         0.828840        0.029663               16

# %%
age=int(input("Age:"))
bmi=float(input("BMI:"))
children=int(input("Children:"))
sex_male=int(input("Sex_Male: 0/1"))
smoker_yes=int(input("Smoker_yes 0 / 1: "))

Future_predictions=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future predictions={}".format(Future_predictions))
# Out:
# Age: 669
# BMI: 19
# Children: 44
# Sex_Male: 0/1 0
# Smoker_yes 0 / 1:  1
# Future predictions=[26756.4929625]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
