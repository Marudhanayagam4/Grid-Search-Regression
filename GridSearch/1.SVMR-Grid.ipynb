# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={"kernel":["rbf","linear","poly","sigmoid"], "gamma":["scale","auto"],"C":[10,50,100,1000,2000]}
grid=GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 50, 100, 1000, 2000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly', 'sigmoid']},
#              verbose=3)

# %%
# print best parameter after tunning
print("R2 score value for best parameter {}".format(grid.best_params_))
# Out:
# R2 score value for best parameter {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.075359      0.005613         0.048138        0.001609      10
# 1        0.062524      0.008319         0.012170        0.003548      10
# 2        0.058546      0.005320         0.012880        0.002373      10
# 3        0.075494      0.000944         0.016387        0.005542      10
# 4        0.073243      0.007413         0.042963        0.007845      10
# 5        0.058875      0.007656         0.010289        0.005723      10
# 6        0.050883      0.005627         0.015462        0.009814      10
# 7        0.074340      0.005598         0.012243        0.005639      10
# 8        0.078012      0.003934         0.042501        0.005452      50
# 9        0.063998      0.004078         0.014551        0.002255      50
# 10       0.060629      0.005223         0.014329        0.006126      50
# 11       0.081518      0.009489         0.012359        0.002885      50
# 12       0.073046      0.004229         0.045465        0.005965      50
# 13       0.077073      0.012401         0.004310        0.005301      50
# 14       0.068432      0.008456         0.007506        0.004266      50
# 15       0.074020      0.002689         0.015065        0.003197      50
# 16       0.070421      0.002898         0.046813        0.006590     100
# 17       0.079333      0.003124         0.003303        0.004194     100
# 18       0.066608      0.006138         0.010748        0.006298     100
# 19       0.074981      0.005786         0.014296        0.006121     100
# 20       0.073093      0.004342         0.047200        0.003406     100
# 21       0.078333      0.005756         0.005341        0.004753     100
# 22       0.062954      0.008136         0.012874        0.006065     100
# 23       0.082740      0.004930         0.009155        0.005091     100
# 24       0.089953      0.008397         0.046872        0.002948    1000
# 25       0.092146      0.008556         0.006130        0.006029    1000
# 26       0.103434      0.019979         0.009217        0.006283    1000
# 27       0.085157      0.006439         0.017764        0.005197    1000
# 28       0.095396      0.007903         0.045606        0.003762    1000
# 29       0.087710      0.005386         0.012807        0.002557    1000
# 30       0.094949      0.018629         0.013426        0.008428    1000
# 31       0.087769      0.011015         0.017131        0.004419    1000
# 32       0.103318      0.006605         0.040509        0.007092    2000
# 33       0.103274      0.006453         0.013469        0.008394    2000
# 34       0.141953      0.015494         0.013427        0.008407    2000
# 35       0.087560      0.002267         0.018877        0.004273    2000
# 36       0.100768      0.002278         0.045550        0.006371    2000
# 37       0.111086      0.007636         0.008606        0.005148    2000
# 38       0.163632      0.032675         0.013896        0.002295    2000
# 39       0.079911      0.010972         0.019407        0.005103    2000
#
#    param_gamma param_kernel  \
# 0        scale          rbf
# 1        scale       linear
# 2        scale         poly
# 3        scale      sigmoid
# 4         auto          rbf
# 5         auto       linear
# 6         auto         poly
# 7         auto      sigmoid
# 8        scale          rbf
# 9        scale       linear
# 10       scale         poly
# 11       scale      sigmoid
# 12        auto          rbf
# 13        auto       linear
# 14        auto         poly
# 15        auto      sigmoid
# 16       scale          rbf
# 17       scale       linear
# 18       scale         poly
# 19       scale      sigmoid
# 20        auto          rbf
# 21        auto       linear
# 22        auto         poly
# 23        auto      sigmoid
# 24       scale          rbf
# 25       scale       linear
# 26       scale         poly
# 27       scale      sigmoid
# 28        auto          rbf
# 29        auto       linear
# 30        auto         poly
# 31        auto      sigmoid
# 32       scale          rbf
# 33       scale       linear
# 34       scale         poly
# 35       scale      sigmoid
# 36        auto          rbf
# 37        auto       linear
# 38        auto         poly
# 39        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 1     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 2       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 4         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 5      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 6        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 7     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 8        {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}           0.158332
# 9     {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}           0.562705
# 10      {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}           0.343754
# 11   {'C': 50, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.305987
# 12        {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}           0.158065
# 13     {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}           0.562705
# 14       {'C': 50, 'gamma': 'auto', 'kernel': 'poly'}           0.347640
# 15    {'C': 50, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.306701
# 16      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 17   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 18     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 19  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 20       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 21    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 22      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 23   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 24     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 25  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.605304
# 26    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 27  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.400044
# 28      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 29   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.605304
# 30     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 31  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.296082
# 32     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 33  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605277
# 34    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 35  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.385658
# 36      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 37   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605277
# 38     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 39  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.401855
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.013244          -0.103775          -0.095165
# 1            0.479601           0.317872           0.337979
# 2            0.071297          -0.046513          -0.024157
# 3            0.076323          -0.046798          -0.040824
# 4            0.013366          -0.103821          -0.095119
# 5            0.479601           0.317872           0.337979
# 6            0.069532          -0.045601          -0.025079
# 7            0.075905          -0.046585          -0.041004
# 8            0.186476           0.032993           0.055287
# 9            0.639891           0.527991           0.555174
# 10           0.389372           0.261939           0.321017
# 11           0.413027           0.234226           0.248710
# 12           0.186988           0.032774           0.055487
# 13           0.639891           0.527991           0.555174
# 14           0.384358           0.265003           0.317976
# 15           0.411565           0.234930           0.247962
# 16           0.338741           0.174086           0.217641
# 17           0.655818           0.553380           0.576939
# 18           0.579373           0.471840           0.537966
# 19           0.563200           0.427152           0.451250
# 20           0.339474           0.173708           0.217991
# 21           0.655818           0.553380           0.576939
# 22           0.575051           0.474839           0.535730
# 23           0.561673           0.428331           0.450454
# 24           0.745892           0.687037           0.717769
# 25           0.588725           0.623230           0.537931
# 26           0.802622           0.799348           0.800587
# 27           0.366097           0.242217           0.288461
# 28           0.746232           0.686773           0.717920
# 29           0.588725           0.623230           0.537931
# 30           0.802622           0.799620           0.800321
# 31           0.372281           0.216401           0.291265
# 32           0.780971           0.794227           0.793983
# 33           0.583646           0.697368           0.532547
# 34           0.805624           0.816612           0.805133
# 35          -0.537098          -0.474912          -0.477335
# 36           0.781092           0.794081           0.794075
# 37           0.583646           0.697368           0.532547
# 38           0.805639           0.816733           0.805143
# 39          -0.508082          -0.452827          -0.751013
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.101602        -0.056634        0.053486               38
# 1            0.324422         0.367569        0.059777               21
# 2           -0.049652         0.001188        0.051594               33
# 3           -0.046521        -0.001635        0.053474               35
# 4           -0.101604        -0.056625        0.053504               37
# 5            0.324422         0.367569        0.059777               21
# 6           -0.049592         0.001107        0.051309               34
# 7           -0.046507        -0.001657        0.053391               36
# 8            0.039299         0.094478        0.064656               32
# 9            0.523959         0.561944        0.041756               15
# 10           0.237569         0.310730        0.054980               24
# 11           0.246294         0.289649        0.066508               27
# 12           0.039281         0.094519        0.064770               31
# 13           0.523959         0.561944        0.041756               15
# 14           0.237765         0.310548        0.053387               25
# 15           0.246348         0.289501        0.065971               28
# 16           0.183403         0.242982        0.065542               30
# 17           0.546881         0.583498        0.038787               13
# 18           0.424478         0.510155        0.054955               18
# 19           0.432199         0.470546        0.049762               19
# 20           0.183375         0.243024        0.065733               29
# 21           0.546881         0.583498        0.038787               13
# 22           0.424640         0.510181        0.053582               17
# 23           0.431701         0.470105        0.049110               20
# 24           0.649174         0.706641        0.034825                7
# 25           0.616726         0.594383        0.030560               11
# 26           0.735555         0.793265        0.030757                4
# 27           0.351407         0.329645        0.056742               23
# 28           0.649158         0.706625        0.034902                8
# 29           0.616726         0.594383        0.030560               11
# 30           0.735580         0.793555        0.031072                3
# 31           0.351325         0.305471        0.054387               26
# 32           0.733663         0.783428        0.027068                5
# 33           0.681425         0.620053        0.061555                9
# 34           0.754962         0.805582        0.029272                1
# 35          -0.111187        -0.397238        0.150976               39
# 36           0.733656         0.783396        0.027014                6
# 37           0.681425         0.620053        0.061555                9
# 38           0.754961         0.805576        0.029233                2
# 39          -0.111859        -0.445127        0.205197               40

# %%
age=int(input("Age:"))
bmi=float(input("BMI:"))
children=int(input("Children:"))
sex_male=int(input("Sex_Male: 0/1"))
smoker_yes=int(input("Smoker_yes 0 / 1: "))

Future_predictions=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future predictions={}".format(Future_predictions))
# Out:
# Age: 25
# BMI: 19
# Children: 0
# Sex_Male: 0/1 1
# Smoker_yes 0 / 1:  0
# Future predictions=[3741007.99643688]
