# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep=dataset[['charges' ]]
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import StandardScaler
scx = StandardScaler()
indep=scx.fit_transform(indep)
indep
# Out:
# array([[-1.43876426, -0.45332   , -0.90861367, -1.0105187 ,  1.97058663],
#        [-1.50996545,  0.5096211 , -0.07876719,  0.98959079, -0.5074631 ],
#        [-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631 ],
#        ...,
#        [-1.50996545,  1.0148781 , -0.90861367, -1.0105187 , -0.5074631 ],
#        [-1.29636188, -0.79781341, -0.90861367, -1.0105187 , -0.5074631 ],
#        [ 1.55168573, -0.26138796, -0.90861367, -1.0105187 ,  1.97058663]])

# %%
scy = StandardScaler()
dep= scy.fit_transform(dep)
dep
# Out:
# array([[ 0.2985838 ],
#        [-0.95368917],
#        [-0.72867467],
#        ...,
#        [-0.96159623],
#        [-0.93036151],
#        [ 1.31105347]])

# %%
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features': [None, 'sqrt', 'log2'],'splitter':['best', 'random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
grid.best_params_
# Out:
# {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}

# %%
y_pred=grid.predict(indep)
y_pred
# Out:
# array([ 0.2985838 , -0.95368917, -0.72867467, ..., -0.96159623,
#        -0.93036151,  1.31105347])

# %%
from sklearn.metrics import r2_score
r2=r2_score(dep, y_pred)
print("The R2 score value for the best parameter {}".format(grid.best_params_),r2)
# Out:
# The R2 score value for the best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'} 0.998667156135576

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011721      0.006596         0.004007        0.004908
# 1        0.008070      0.006859         0.000000        0.000000
# 2        0.005898      0.005218         0.000000        0.000000
# 3        0.003302      0.004421         0.002002        0.004004
# 4        0.011918      0.001565         0.001381        0.001691
# 5        0.006691      0.004208         0.000000        0.000000
# 6        0.007106      0.003961         0.001098        0.002197
# 7        0.006967      0.005370         0.003127        0.006254
# 8        0.006343      0.005215         0.001370        0.002006
# 9        0.002339      0.004679         0.006062        0.004949
# 10       0.004374      0.004709         0.000000        0.000000
# 11       0.004013      0.004915         0.002001        0.004003
# 12       0.057051      0.004830         0.000000        0.000000
# ...

# %%
import pickle
filename="final_model.sav"
pickle.dump(grid,open(filename, "wb"))
pickle.dump(scx,open("Standard_Scaler_X.pkl",'wb'))
pickle.dump(scy,open("Standard_Scaler_Y.pkl",'wb'))
