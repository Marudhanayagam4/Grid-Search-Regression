# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep=dataset[['charges' ]]
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features': [None, 'sqrt', 'log2'],'splitter':['best', 'random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
y_pred=grid.predict(indep)
y_pred
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
from sklearn.metrics import r2_score
r2=r2_score(dep, y_pred)
print("The R2 score value for the best parameter {}".format(grid.best_params_),r2)
# Out:
# The R2 score value for the best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'} 0.998667156135576

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016147      0.004958         0.004046        0.004955
# 1        0.010116      0.000046         0.008096        0.004048
# 2        0.012139      0.004041         0.006055        0.004944
# 3        0.010119      0.000062         0.008105        0.004053
# 4        0.013215      0.003573         0.000000        0.000000
# 5        0.010485      0.007000         0.003066        0.003712
# 6        0.013360      0.003829         0.002755        0.004107
# 7        0.010174      0.000096         0.006435        0.004529
# 8        0.009175      0.003736         0.004099        0.005021
# 9        0.010184      0.000084         0.002056        0.004113
# 10       0.010143      0.000077         0.006099        0.004980
# 11       0.008144      0.004073         0.006063        0.004950
# 12       0.060582      0.003175         0.006064        0.004952
# 13       0.041400      0.002074         0.008067        0.004034
# 14       0.036356      0.004947         0.000000        0.000000
# 15       0.024201      0.004930         0.004046        0.004956
# 16       0.038346      0.004027         0.002014        0.004027
# 17       0.027826      0.004635         0.007051        0.004039
# 18       0.014130      0.004934         0.006048        0.004938
# 19       0.010098      0.000016         0.006066        0.004953
# 20       0.012095      0.004020         0.004041        0.004930
# 21       0.008048      0.004024         0.004075        0.004945
# 22       0.012120      0.004041         0.008073        0.004037
# 23       0.012871      0.003375         0.008645        0.001782
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.729969
# 1   {'criterion': 'squared_error', 'max_features':...           0.635852
# 2   {'criterion': 'squared_error', 'max_features':...           0.754580
# 3   {'criterion': 'squared_error', 'max_features':...           0.730757
# 4   {'criterion': 'squared_error', 'max_features':...           0.728163
# 5   {'criterion': 'squared_error', 'max_features':...           0.666365
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.717778
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.724063
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.704211
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.601719
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.632074
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.653379
# 12  {'criterion': 'absolute_error', 'max_features'...           0.730320
# 13  {'criterion': 'absolute_error', 'max_features'...           0.657668
# 14  {'criterion': 'absolute_error', 'max_features'...           0.677560
# 15  {'criterion': 'absolute_error', 'max_features'...           0.741093
# 16  {'criterion': 'absolute_error', 'max_features'...           0.608195
# 17  {'criterion': 'absolute_error', 'max_features'...           0.707995
# 18  {'criterion': 'poisson', 'max_features': None,...           0.738209
# 19  {'criterion': 'poisson', 'max_features': None,...           0.607027
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.654971
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.694368
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.765619
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.659840
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.614099           0.742090           0.686340
# 1            0.591617           0.698251           0.644124
# 2            0.594311           0.747179           0.632916
# 3            0.613001           0.716964           0.654369
# 4            0.484163           0.722162           0.716918
# 5            0.633752           0.623219           0.567892
# 6            0.652378           0.726527           0.740480
# 7            0.589616           0.719754           0.616164
# 8            0.679678           0.723675           0.719511
# 9            0.631980           0.531272           0.669923
# 10           0.578225           0.599435           0.674974
# 11           0.370527           0.670745           0.716152
# 12           0.648542           0.730455           0.706267
# 13           0.615639           0.709765           0.761404
# 14           0.601990           0.736256           0.594461
# 15           0.586648           0.610021           0.702859
# 16           0.568655           0.699094           0.590279
# 17           0.572600           0.666580           0.704276
# 18           0.662179           0.759052           0.733031
# 19           0.634945           0.676206           0.752730
# 20           0.643834           0.750537           0.617726
# 21           0.607763           0.576217           0.674915
# 22           0.598006           0.657544           0.708848
# 23           0.477458           0.694377           0.578192
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.666995         0.687899        0.046027                4
# 1            0.722443         0.658458        0.046608               16
# 2            0.598338         0.665465        0.071059               15
# 3            0.655299         0.674078        0.043642               12
# 4            0.632270         0.656735        0.093150               17
# 5            0.681753         0.634596        0.039529               20
# 6            0.676081         0.702649        0.033055                3
# 7            0.731844         0.676288        0.060639               11
# 8            0.589806         0.683376        0.049260                7
# 9            0.677118         0.622402        0.053059               22
# 10           0.610995         0.619140        0.032904               23
# 11           0.643185         0.610798        0.122707               24
# 12           0.748985         0.712914        0.034928                2
# 13           0.687299         0.686355        0.049000                5
# 14           0.794557         0.680965        0.077061                9
# 15           0.711882         0.670501        0.060715               13
# 16           0.754443         0.644133        0.070821               18
# 17           0.693296         0.668949        0.050307               14
# 18           0.697874         0.718069        0.034178                1
# 19           0.712004         0.676582        0.052202               10
# 20           0.747352         0.682884        0.055286                8
# 21           0.639285         0.638510        0.043062               19
# 22           0.692239         0.684451        0.055571                6
# 23           0.750907         0.632155        0.095481               21

# %%
import pickle
filename="final_model.sav"
pickle.dump(open(filename, "wb"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 import pickle
#       2 filename="final_model.sav"
# ----> 3 pickle.dump(open(filename, "wb"))
#
# TypeError: dump() missing required argument 'file' (pos 2)
